# %% [markdown]
# <a href="https://colab.research.google.com/github/JJJSuperCat/BR2211/blob/main/week02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load the rpy2.ipython extension to allows writing and executing R code directly within a Python environment of Google Colab. Once loaded, you can preface any cell with %%R to run the code inside it as R code.

# %%
# %%capture
# %pip install rpy2

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# x <- c(1,2,3,4)
# mean(x)
# Out:
# [1] 2.5
